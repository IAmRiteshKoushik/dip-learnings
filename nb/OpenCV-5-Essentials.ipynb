# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grayscaling an Image
#
# A second transformation is added everytime as matplotlib reads in BGR

# %%
img = cv.imread("../Photos/park.jpg")

# Changing to grayscale
gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)

# Creating subplots
fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.set_title("Original Image")
ax1.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
ax1.axis("off")

ax2.set_title("Grayscaled Image")
ax2.imshow(cv.cvtColor(gray, cv.COLOR_BGR2RGB))
ax2.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Blurring an Image

# %%
# Params - srcImg, 2x2 tuple
blur = cv.GaussianBlur(img, (3, 3), cv.BORDER_DEFAULT)

# -- You might have to save the image in-order to properly 
# see the blur as the display resolution is horrible in notebooks
# cv.imwrite("../Photos/result-blur.png", blur)


# Creating subplots
fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.set_title("Original Image")
ax1.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
ax1.axis("off")

ax2.set_title("Blurred Image")
ax2.imshow(cv.cvtColor(blur, cv.COLOR_BGR2RGB))
ax2.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Edge Cascade - Canny Edge detector (there are many)
# Trying to find all the edges that are present in an image
#
# - Increase number of edges using RGB
# - Reduce number of edges using blur picture (falls below threshold)

# %%
# Params - image-matrix, lowThreshold, maxThreshold
canny = cv.Canny(img, 125, 175)

# Creating subplots
fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.set_title("Original Image")
ax1.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
ax1.axis("off")

ax2.set_title("Edge-cascade Image")
ax2.imshow(cv.cvtColor(canny, cv.COLOR_BGR2RGB))
ax2.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dilating Images

# %%
# Params - imgSrc, kernel-size, iterations
dilated = cv.dilate(canny, (3, 3), iterations=1)

# Creating subplots
fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.set_title("Original Image")
ax1.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
ax1.axis("off")

ax2.set_title("Edge-cascade Image")
ax2.imshow(cv.cvtColor(canny, cv.COLOR_BGR2RGB))
ax2.axis("off")

plt.tight_layout()
plt.show()
